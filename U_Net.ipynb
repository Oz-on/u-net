# %% [markdown]
# # Semantic Segmentation using U-Net
#
# In this notebook I am going to implement U-Net architecture manually and use it for semantic image segmentation on medical imaging

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
from IPython.display import clear_output
import matplotlib.pyplot as plt

# %%
# Load the dataset
dataset, info = tfds.load('oxford_iiit_pet:3.*.*', with_info=True)
# Out:
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/oxford_iiit_pet/3.2.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Shuffling /root/tensorflow_datasets/oxford_iiit_pet/3.2.0.incomplete2TEDOV/oxford_iiit_pet-train.tfrecord*...:…
# Generating test examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/oxford_iiit_pet/3.2.0.incomplete2TEDOV/oxford_iiit_pet-test.tfrecord*...: …
# Dataset oxford_iiit_pet downloaded and prepared to /root/tensorflow_datasets/oxford_iiit_pet/3.2.0. Subsequent calls will reuse this data.

# %%
def normalize(input_image, input_mask):
  input_image = tf.cast(input_image, tf.float32) / 255.0
  input_mask -= 1
  return input_image, input_mask

# %%
def load_image(datapoint):
  input_image = tf.image.resize(datapoint['image'], (128, 128))
  input_mask = tf.image.resize(
      datapoint['segmentation_mask'],
      (128, 128),
      method = tf.image.ResizeMethod.NEAREST_NEIGHBOR,
  )

  input_image, input_mask = normalize(input_image, input_mask)

  return input_image, input_mask

# %%
TRAIN_LENGTH = info.splits['train'].num_examples
BATCH_SIZE = 64
BUFFER_SIZE = 1000
STEPS_PER_EPOCH = TRAIN_LENGTH // BATCH_SIZE

# %%
train_images = dataset['train'].map(load_image, num_parallel_calls=tf.data.AUTOTUNE)
test_images = dataset['test'].map(load_image, num_parallel_calls=tf.data.AUTOTUNE)

# %%
class Augment(tf.keras.layers.Layer):
  def __init__(self, seed=42):
    super().__init__()
    # Both use the same seed, so they'll make the same random changes
    self.augment_inputs = tf.keras.layers.RandomFlip(mode='horizontal', seed=seed)
    self.augment_labels = tf.keras.layers.RandomFlip(mode='horizontal', seed=seed)

  def call(self, inputs, labels):
    inputs = self.augment_inputs(inputs)
    labels = self.augment_labels(labels)
    return inputs, labels

# %%
# Input pipeline
train_batches = (
    train_images
    .cache()
    .shuffle(BUFFER_SIZE)
    .batch(BATCH_SIZE)
    .repeat()
    .map(Augment())
    .prefetch(buffer_size=tf.data.AUTOTUNE)
)

test_batches = test_images.batch(BATCH_SIZE)

# %%
# Visualise an image example and its corresponding mask from the dataset
def display(display_list):
  plt.figure(figsize=(15,15))

  title = ['Input Image', 'True Mask', 'Predicted Mask']

  for i in range(len(display_list)):
    plt.subplot(1, len(display_list), i+1)
    plt.title(title[i])
    plt.imshow(tf.keras.utils.array_to_img(display_list[i]))
    plt.axis('off')

  plt.show()

# %%
for images, masks in train_batches.take(2):
  sample_image, sample_mask = images[0], masks[0]
  display([sample_image, sample_mask])

# %%
# Build the model
inputs = tf.keras.layers.Input((128, 128, 3))

# 1st block
c1 = tf.keras.layers.Conv2D(16, (3,3), activation='relu', kernel_initializer='he_normal', padding='same')(inputs)
c1 = tf.keras.layers.Dropout(0.1)(c1)
c1 = tf.keras.layers.Conv2D(16, (3,3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
p1 = tf.keras.layers.MaxPooling2D((2,2))(c1)

# 2nd block
c2 = tf.keras.layers.Conv2D(32, (3,3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
c2 = tf.keras.layers.Dropout(0.1)(c2)
c2 = tf.keras.layers.Conv2D(32, (3,3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
p2 = tf.keras.layers.MaxPooling2D((2,2))(c2)

# 3rd block
c3 = tf.keras.layers.Conv2D(64, (3,3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
c3 = tf.keras.layers.Dropout(0.2)(c3)
c3 = tf.keras.layers.Conv2D(64, (3,3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
p3 = tf.keras.layers.MaxPooling2D((2,2))(c3)

# 4th block
c4 = tf.keras.layers.Conv2D(128, (3,3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
c4 = tf.keras.layers.Dropout(0.2)(c4)
c4 = tf.keras.layers.Conv2D(128, (3,3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
p4 = tf.keras.layers.MaxPooling2D((2,2))(c4)

# 5th block 
c5 = tf.keras.layers.Conv2D(256, (3,3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
c5 = tf.keras.layers.Dropout(0.2)(c5)
c5 = tf.keras.layers.Conv2D(256, (3,3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)

# Expansive path
u6 = tf.keras.layers.Conv2DTranspose(128, (2,2), strides=(2,2), padding='same')(c5)
u6 = tf.keras.layers.concatenate([u6, c4])
c6 = tf.keras.layers.Conv2D(128, (3,3), activation='relu', kernel_initializer='he_normal', padding='same')(u6)
c6 = tf.keras.layers.Dropout(0.2)(c6)
c6 = tf.keras.layers.Conv2D(128, (3,3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)

u7 = tf.keras.layers.Conv2DTranspose(64, (2,2), strides=(2,2), padding='same')(c6)
u7 = tf.keras.layers.concatenate([u7, c3])
c7 = tf.keras.layers.Conv2D(64, (3,3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
c7 = tf.keras.layers.Dropout(0.2)(c7)
c7 = tf.keras.layers.Conv2D(64, (3,3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)

u8 = tf.keras.layers.Conv2DTranspose(32, (2,2), strides=(2,2), padding='same')(c7)
u8 = tf.keras.layers.concatenate([u8, c2])
c8 = tf.keras.layers.Conv2D(32, (3,3), activation='relu', kernel_initializer='he_normal', padding='same')(u8)
c8 = tf.keras.layers.Dropout(0.1)(c8)
c8 = tf.keras.layers.Conv2D(32, (3,3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)

u9 = tf.keras.layers.Conv2DTranspose(16, (2,2), strides=(2,2), padding='same')(c8)
u9 = tf.keras.layers.concatenate([u9, c1], axis=3)
c9 = tf.keras.layers.Conv2D(16, (3,3), activation='relu', kernel_initializer='he_normal', padding='same')(u9)
c9 = tf.keras.layers.Dropout(0.1)(c9)
c9 = tf.keras.layers.Conv2D(16, (3,3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)

outputs = tf.keras.layers.Conv2DTranspose(3, (3,3), padding='same', activation='sigmoid')(c9)

# %%
model = tf.keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer='adam', 
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
              metrics=['accuracy'])

model.summary()
tf.keras.utils.plot_model(model, show_shapes=True)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d_37 (Conv2D)             (None, 128, 128, 16  448         ['input_3[0][0]']
#                                 )
#
#  dropout_18 (Dropout)           (None, 128, 128, 16  0           ['conv2d_37[0][0]']
#                                 )
#
#  conv2d_38 (Conv2D)             (None, 128, 128, 16  2320        ['dropout_18[0][0]']
#                                 )
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 64, 64, 16)  0           ['conv2d_38[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 64, 64, 32)   4640        ['max_pooling2d_8[0][0]']
#
#  dropout_19 (Dropout)           (None, 64, 64, 32)   0           ['conv2d_39[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 64, 64, 32)   9248        ['dropout_19[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 32, 32, 32)  0           ['conv2d_40[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 32, 32, 64)   18496       ['max_pooling2d_9[0][0]']
#
#  dropout_20 (Dropout)           (None, 32, 32, 64)   0           ['conv2d_41[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 32, 32, 64)   36928       ['dropout_20[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 16, 16, 64)  0           ['conv2d_42[0][0]']
#  )
#
#  conv2d_43 (Conv2D)             (None, 16, 16, 128)  73856       ['max_pooling2d_10[0][0]']
#
#  dropout_21 (Dropout)           (None, 16, 16, 128)  0           ['conv2d_43[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 16, 16, 128)  147584      ['dropout_21[0][0]']
#
#  max_pooling2d_11 (MaxPooling2D  (None, 8, 8, 128)   0           ['conv2d_44[0][0]']
#  )
#
#  conv2d_45 (Conv2D)             (None, 8, 8, 256)    295168      ['max_pooling2d_11[0][0]']
#
#  dropout_22 (Dropout)           (None, 8, 8, 256)    0           ['conv2d_45[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 8, 8, 256)    590080      ['dropout_22[0][0]']
#
#  conv2d_transpose_9 (Conv2DTran  (None, 16, 16, 128)  131200     ['conv2d_46[0][0]']
#  spose)
#
#  concatenate_8 (Concatenate)    (None, 16, 16, 256)  0           ['conv2d_transpose_9[0][0]',
#                                                                   'conv2d_44[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 16, 16, 128)  295040      ['concatenate_8[0][0]']
#
#  dropout_23 (Dropout)           (None, 16, 16, 128)  0           ['conv2d_47[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 16, 16, 128)  147584      ['dropout_23[0][0]']
#
#  conv2d_transpose_10 (Conv2DTra  (None, 32, 32, 64)  32832       ['conv2d_48[0][0]']
#  nspose)
#
#  concatenate_9 (Concatenate)    (None, 32, 32, 128)  0           ['conv2d_transpose_10[0][0]',
#                                                                   'conv2d_42[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 32, 32, 64)   73792       ['concatenate_9[0][0]']
#
#  dropout_24 (Dropout)           (None, 32, 32, 64)   0           ['conv2d_49[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 32, 32, 64)   36928       ['dropout_24[0][0]']
#
#  conv2d_transpose_11 (Conv2DTra  (None, 64, 64, 32)  8224        ['conv2d_50[0][0]']
#  nspose)
#
#  concatenate_10 (Concatenate)   (None, 64, 64, 64)   0           ['conv2d_transpose_11[0][0]',
#                                                                   'conv2d_40[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 64, 64, 32)   18464       ['concatenate_10[0][0]']
#
#  dropout_25 (Dropout)           (None, 64, 64, 32)   0           ['conv2d_51[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 64, 64, 32)   9248        ['dropout_25[0][0]']
#
#  conv2d_transpose_12 (Conv2DTra  (None, 128, 128, 16  2064       ['conv2d_52[0][0]']
#  nspose)                        )
#
#  concatenate_11 (Concatenate)   (None, 128, 128, 32  0           ['conv2d_transpose_12[0][0]',
#                                 )                                 'conv2d_38[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 128, 128, 16  4624        ['concatenate_11[0][0]']
#                                 )
#
#  dropout_26 (Dropout)           (None, 128, 128, 16  0           ['conv2d_53[0][0]']
#                                 )
#
#  conv2d_54 (Conv2D)             (None, 128, 128, 16  2320        ['dropout_26[0][0]']
#                                 )
#
#  conv2d_transpose_13 (Conv2DTra  (None, 128, 128, 3)  435        ['conv2d_54[0][0]']
#  nspose)
#
# ==================================================================================================
# Total params: 1,941,523
# Trainable params: 1,941,523
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
def create_mask(pred_mask):
  pred_mask = tf.math.argmax(pred_mask, axis=-1)
  pred_mask = pred_mask[..., tf.newaxis]
  return pred_mask[0]

# %%
def show_predictions(dataset=None, num=1):
  if dataset:
    for image, mask in dataset.take(num):
      pred_mask = model.predict(image)
      display([image[0], mask[0], create_mask(pred_mask)])
  else:
    display([sample_image, sample_mask, create_mask(model.predict(sample_image[tf.newaxis, ...]))])

# %%
show_predictions()
# Out:
# 1/1 [==============================] - 0s 288ms/step

# %%
class DisplayCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs=None):
    clear_output(wait=True)
    show_predictions()
    print('\nSample Prediction after epoch {}\n'.format(epoch+1))

# %%
EPOCHS = 20
VAL_SUBSPLITS = 5
VALIDATION_STEPS = info.splits['test'].num_examples//BATCH_SIZE//VAL_SUBSPLITS

model_history = model.fit(train_batches, epochs=EPOCHS,
                          steps_per_epoch=STEPS_PER_EPOCH,
                          validation_steps=VALIDATION_STEPS,
                          validation_data=test_batches,
                          callbacks=[DisplayCallback()])
# Out:
# 1/1 [==============================] - 0s 25ms/step
# Sample Prediction after epoch 20
#
# 57/57 [==============================] - 3s 52ms/step - loss: 0.2846 - accuracy: 0.8887 - val_loss: 0.3976 - val_accuracy: 0.8612

# %%
loss = model_history.history['loss']
val_loss = model_history.history['val_loss']

plt.figure()
plt.plot(model_history.epoch, loss, 'r', label='Training loss')
plt.plot(model_history.epoch, val_loss, 'bo', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.ylim([0, 1])
plt.legend()
plt.show()

# %%
show_predictions(test_batches, 3)
# Out:
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
